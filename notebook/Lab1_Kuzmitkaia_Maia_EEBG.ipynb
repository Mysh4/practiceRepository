# %% [markdown]
# Deleting everything from sample_data

# %%
# %%bash
# pwd
# cd sample_data
# rm *
# Out:
# /content

# %% [markdown]
# Renaming sample_data into Repository

# %%
# %%bash
# mv sample_data Repository
# ls
# Out:
# Repository

# %% [markdown]
# Creating README.txt in Repository

# %%
# %%bash
# cd Repository
# touch README.txt
# ls
# Out:
# README.txt

# %% [markdown]
# Creating 4 subdirectories "summarydata", "notebook", "figure", "multipanel" in Repository

# %%
# %%bash
# cd Repository
# mkdir summarydata notebook figure multipanel
# ls
# Out:
# figure
# multipanel
# notebook
# README.txt
# summarydata

# %% [markdown]
# Creating files in summary_data

# %%
# %%bash
# cd Repository/summarydata/
# touch README.txt Figure_1adata.csv Figure_1bdata.csv Figure_2adata.csv Figure_2bdata.csv Figure_2cdata.csv
# ls
# Out:
# Figure_1adata.csv
# Figure_1bdata.csv
# Figure_2adata.csv
# Figure_2bdata.csv
# Figure_2cdata.csv
# README.txt

# %% [markdown]
# Creating files in notebook

# %%
# %%bash
# cd Repository/notebook/
# touch README.txt Figure1.ipynb Figure2.ipynb
# ls
# Out:
# Figure1.ipynb
# Figure2.ipynb
# README.txt

# %% [markdown]
# Creating files in figure

# %%
# %%bash
# cd Repository/figure/
# touch README.txt Figure1a.pdf Figure1b.pdf Figure2a.pdf Figure2b.pdf Figure2c.pdf
# ls
# Out:
# Figure1a.pdf
# Figure1b.pdf
# Figure2a.pdf
# Figure2b.pdf
# Figure2c.pdf
# README.txt

# %% [markdown]
# Creating files in multipanel

# %%
# %%bash
# cd Repository/multipanel/
# touch README.txt Figure1.ai Figure2.ai
# ls
# Out:
# Figure1.ai
# Figure2.ai
# README.txt

# %% [markdown]
# Task is done!
